# %%
import pandas as pd
data = pd.read_csv("data.csv")

# %%
data
# Out:
#       ICUSTAY_ID  creatinine   po2  fio2  pco2  bp_min  bp_max  pain    k  \
# 0            832       117.0   8.6   NaN   5.5   150.0   159.0   3.0  4.6
# 1            837        42.0   5.2   NaN   5.7   126.0   126.0   1.0  4.5
# 2            848        32.0  18.1  21.0   4.6    92.0   105.0   0.0  4.6
# 3            849       100.0   9.8   NaN   5.6   126.0   147.0   3.0  5.2
# 4            852        52.0   5.1   NaN   7.4   135.0   139.0   2.0  4.7
# ...          ...         ...   ...   ...   ...     ...     ...   ...  ...
# 3952       11764        28.0   NaN   NaN   NaN   159.0   159.0   0.0  3.1
# 3953       11765       133.0   9.9  35.0   4.9    81.0   117.0   0.0  4.4
# 3954       11766        82.0   8.7  30.0   4.2    80.0   102.0   0.0  4.8
# 3955       11767        87.0   4.5  35.0   6.4   112.0   140.0   0.0  4.5
# 3956       11768        35.0  10.1  35.0   3.8   100.0   122.0   0.0  4.7
#
#       hr_min  ...  resp_min  resp_max  haemoglobin  spo2_min  spo2_max  \
# ...

# %% [markdown]
# imputation of missing values
